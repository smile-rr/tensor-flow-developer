# %% [markdown]
# <a href="https://colab.research.google.com/github/smile-rr/tensor-flow-developer/blob/main/tf_C1_W1_helloworld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(units=1)
])
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - loss: 15.2883
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 12.2699
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 9.8902
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 8.0131
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 6.5315
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 5.3612
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 4.4359
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 3.7034
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 3.1227
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.6616
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.2946
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.0017
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 1.7673
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.5789
# Epoch 15/500
# ...

# %%
print(f"model predicated: {model.predict(np.array([10.0]), verbose=0).item():.5f}")
# Out:
# model predicated: 18.98158
